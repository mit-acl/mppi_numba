# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import time
import math
import copy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../mppi_numba')
from density import Density, GaussianMixture
from terrain import Terrain, TDM_Numba, TractionGrid
from visualization import TDM_Visualizer, vis_density, vis_density_as_pmf
from mppi import MPPI_Numba
from config import Config
import pickle

# %%
# What percentile of the speed distribution to compute conditional expectation?
cvar_alpha =0.3

pmf_bounds = [0, 1.0]
bush_weights = [0.6, 0.4]
bush_means= [0, 0.8]
bush_std = [0.1, 0.1]
dirt_weights = [1]
dirt_means = [0.8]
dirt_std = [0.1]
bush_lin_gm = GaussianMixture(sample_bounds=pmf_bounds, pmf_bounds=pmf_bounds, weights=bush_weights, means=bush_means, stds=bush_std)
bush_ang_gm = GaussianMixture(sample_bounds=pmf_bounds, pmf_bounds=pmf_bounds, weights=bush_weights, means=bush_means, stds=bush_std)
dirt_lin_gm = GaussianMixture(sample_bounds=pmf_bounds, pmf_bounds=pmf_bounds, weights=dirt_weights, means=dirt_means, stds=dirt_std)
dirt_ang_gm = GaussianMixture(sample_bounds=pmf_bounds, pmf_bounds=pmf_bounds, weights=dirt_weights, means=dirt_means, stds=dirt_std)

bush = Terrain(name='Vegetation', lin_density=bush_lin_gm, ang_density=bush_ang_gm, cvar_alpha=cvar_alpha, rgb=np.array((0,250,0))/255.0)
dirt = Terrain(name='Dirt', lin_density=dirt_lin_gm, ang_density=dirt_ang_gm, cvar_alpha=cvar_alpha, rgb=np.array((200,190,160))/255.0)
print(bush)
print(dirt)

ID2NAME = {
    0: dirt.name,
    1: bush.name
}
NAME2TERRAIN = {
    bush.name: bush,
    dirt.name: dirt
}

num_bins=20
b_lin_values, b_lin_pmf = bush_lin_gm.get_pmf(num_bins=num_bins)
b_ang_values, b_ang_pmf = bush_ang_gm.get_pmf(num_bins=num_bins)
d_lin_values, d_lin_pmf = dirt_lin_gm.get_pmf(num_bins=num_bins)
d_ang_values, d_ang_pmf = dirt_ang_gm.get_pmf(num_bins=num_bins)
LIN_TERRAIN2PMG = {
    bush: (b_lin_values, b_lin_pmf),
    dirt: (d_lin_values, d_lin_pmf),
}
ANG_TERRAIN2PMG = {
    bush: (b_ang_values, b_ang_pmf),
    dirt: (d_ang_values, d_ang_pmf),
}
# -------------- Visualize the speed distribution for each class---------
fig, axes = plt.subplots(1, 4, figsize=(16, 3))
vis_density(axes[0], bush_lin_gm, bush, vis_cvar_alpha=cvar_alpha, title="Veg (lin. traction)", color=bush.rgb)
vis_density(axes[1], bush_ang_gm, bush, vis_cvar_alpha=cvar_alpha, title="Veg (ang. traction)", color=bush.rgb)
vis_density(axes[2], dirt_lin_gm, dirt, vis_cvar_alpha=cvar_alpha, title="Dirt (lin. traction)", color=dirt.rgb)
vis_density(axes[3], dirt_ang_gm, dirt, vis_cvar_alpha=cvar_alpha, title="Dirt (ang. traction)", color=dirt.rgb)

fig, axes = plt.subplots(1, 4, figsize=(16, 3))
vis_density_as_pmf(axes[0], bush_lin_gm, bush, num_bins=num_bins, title="Veg (lin. traction)", color=bush.rgb)
vis_density_as_pmf(axes[1], bush_ang_gm, bush, num_bins=num_bins, title="Veg (ang. traction)", color=bush.rgb)
vis_density_as_pmf(axes[2], dirt_lin_gm, dirt, num_bins=num_bins, title="Dirt (lin. traction)", color=dirt.rgb)
vis_density_as_pmf(axes[3], dirt_ang_gm, dirt, num_bins=num_bins, title="Dirt (ang. traction)", color=dirt.rgb)

plt.tight_layout()
plt.show()
# Out:
# Terrain Vegetation has the following properties for linear and angular tractions.
# mean=(0.49, 0.48), std=(0.36, 0.36), cvar(0.30)=(0.05, 0.05) (computed from 10000.0 saved samples)
# Terrain Dirt has the following properties for linear and angular tractions.
# mean=(0.79, 0.79), std=(0.09, 0.09), cvar(0.30)=(0.68, 0.68) (computed from 10000.0 saved samples)

# %% [markdown]
# ### Methods to pre-generate the random problem setup (start, goal, envs with grass in middle)
#
# 10x10 cells, with the center 8x8 cells populated with grass
#
# * Function to run a trial based on specification
# * Use the same semantic env for N trials
# * Use the same realization for different methods
# * Log using panda dataframe and post process

# %%
# Trial function
def trial(semantic_grid, traction_grid, dt, max_speed, max_steps, num_pmf_bins, bin_values, bin_values_bounds, xlimits, ylimits, res, mppi_params):
  # Construct the traction maps
  lin_tdm = TDM_Numba(max_speed=max_speed)
  ang_tdm = TDM_Numba(max_speed=max_speed)
  lin_tdm.set_TDM_from_semantic_grid(semantic_grid, res, num_pmf_bins, bin_values, bin_values_bounds, 
                    xlimits, ylimits, ID2NAME, NAME2TERRAIN, LIN_TERRAIN2PMG,
                    mppi_params["use_det_dynamics"], mppi_params['cvar_alpha'], mppi_params["use_nom_dynamics_with_speed_map"])
  ang_tdm.set_TDM_from_semantic_grid(semantic_grid, res, num_pmf_bins, bin_values, bin_values_bounds, 
                      xlimits, ylimits, ID2NAME, NAME2TERRAIN, ANG_TERRAIN2PMG,
                      mppi_params["use_det_dynamics"], mppi_params['cvar_alpha'], mppi_params["use_nom_dynamics_with_speed_map"])

  # Construct the MPPI planner + initialize the GPU variables
  mppi_planner = MPPI_Numba()
  mppi_planner.setup(mppi_params, lin_tdm, ang_tdm)
  mppi_planner.init_device_vars_before_solving()

  # Loop
  xhist = np.zeros((max_steps+1, 3))*np.nan
  uhist = np.zeros((max_steps, 2))*np.nan
  xhist[0] = mppi_params['x0']
  goal_reached=False
  for t in range(max_steps):
    # Solve
    useq = mppi_planner.solve()
    u_curr = useq[0]
    uhist[t] = u_curr

    # Simulate state forward using the sampled map
    lt, at = traction_grid.get(xhist[t,0], xhist[t,1])
    xhist[t+1, 0] = xhist[t, 0] + dt*lt*np.cos(xhist[t, 2])*u_curr[0]
    xhist[t+1, 1] = xhist[t, 1] + dt*lt*np.sin(xhist[t, 2])*u_curr[0]
    xhist[t+1, 2] = xhist[t, 2] + dt*at*u_curr[1]
    
    # Update MPPI state (x0, useq)
    mppi_planner.shift_and_update(xhist[t+1], useq, num_shifts=1)

    # Goal check
    if np.linalg.norm(xhist[t+1, :2] - mppi_params['xgoal']) <=mppi_params['goal_tolerance']:
      goal_reached = True
      break
  
  # Return trial_info
  trial_logger = dict(
    time_to_goal=(t+1)*dt if goal_reached else np.nan,
    success=goal_reached,
    # xhist=xhist,
    # uhist=uhist
  )
  return trial_logger



def run_trials(cfg, max_speed, max_steps, grid_shape, mud_margin, res, num_pmf_bins, bin_values, bin_values_bounds, default_mppi_params,
               grass_density_list, envs_per_density, trials_per_env, alpha_list, method_list):
  loggers = []
  # For each grass density
  for density_i, grass_density in enumerate(grass_density_list):
    # For each sampled semantic map, pre-generate realizations for evaluation (same more all methods)
    for sem_map_i in range(envs_per_density):
      # Generate semantic map
      semantic_grid = np.zeros(grid_shape, dtype=np.int8)
      rand_num = np.random.rand(grid_shape[0]-2*mud_margin, grid_shape[1]-2*mud_margin)
      semantic_grid[mud_margin:-mud_margin, mud_margin:-mud_margin][rand_num<grass_density] = 1
      xlimits = (0,semantic_grid.shape[1]*res)
      ylimits = (0,semantic_grid.shape[0]*res)

      # Pre-generate realizations of the map
      lin_tdm = TDM_Numba(max_speed=max_speed)
      lin_tdm.set_TDM_from_semantic_grid(semantic_grid, res, num_pmf_bins, bin_values, bin_values_bounds, 
                    xlimits, ylimits, ID2NAME, NAME2TERRAIN, LIN_TERRAIN2PMG)
      traction_grid_samples = [lin_tdm.sample_grids_true_dist() for _ in range(trials_per_env)]

      # For each method
      for method_i, method in enumerate(method_list):
        # For each alpha
        for alpha_i, alpha in enumerate(alpha_list):
          print(" grass_density={} ({}/{}), sem_map({}/{}), method={}({}/{}), alpha={}({}/{})".format(
              grass_density, density_i+1, len(grass_density_list),
              sem_map_i+1, envs_per_density, 
              method, method_i+1, len(method_list),
              alpha, alpha_i+1, len(alpha_list),
            ))
          t_map_realizations = time.time()
          # For each realized map
          for map_sample_i, traction_grid in enumerate(traction_grid_samples):
            # Update the MPPI parameters
            trial_mppi_params = copy.deepcopy(default_mppi_params)
            trial_mppi_params['cvar_alpha'] = alpha
            if method == 'risk_dyn':
              trial_mppi_params['use_det_dynamics'] = True
              trial_mppi_params['use_nom_dynamics_with_speed_map'] = False
            elif method == 'nom_dyn_risk_cost':
              trial_mppi_params['use_det_dynamics'] = False
              trial_mppi_params['use_nom_dynamics_with_speed_map'] = True
            elif method == 'noisy_dyn':
              trial_mppi_params['use_det_dynamics'] = False
              trial_mppi_params['use_nom_dynamics_with_speed_map'] = False
            else:
              assert False, "Method {} is not expected.".format(method)
            
            # Run trial
            trial_logger = trial(
              semantic_grid, 
              traction_grid, 
              cfg.dt, 
              max_speed, 
              max_steps, 
              num_pmf_bins, 
              bin_values, 
              bin_values_bounds, 
              xlimits, 
              ylimits, 
              res, 
              trial_mppi_params)
            
            # Save other details
            trial_logger['grass_density'] = grass_density
            trial_logger['grass_density_index'] = density_i
            trial_logger['sem_map_index'] = sem_map_i
            trial_logger['method'] = method
            trial_logger['alpha'] = alpha
            trial_logger['map_sample_index'] = map_sample_i

            loggers.append(trial_logger)
          t_elapsed = time.time()-t_map_realizations
          print("{} map realizations took {:.2f}s ({:.2f}s on avg)".format(trials_per_env, t_elapsed, t_elapsed/trials_per_env))

  return pd.DataFrame(loggers)

# %%
# ------------- Map configs ------------
grid_shape = (9, 9)
mud_margin = 1
# grid_shape = (11, 11)
# mud_margin = 2
res = 1.0

num_pmf_bins = len(d_ang_pmf) # Assume numbers of bins are the same for linear and angular components for now
bin_values = b_lin_values
bin_values_bounds = (np.min(b_lin_values), np.max(b_lin_values))

# ------------- Problem configuration ------------
cfg = Config()
u_seq0 = np.zeros((cfg.num_steps, 2), dtype=float)
# x0=np.array([0.5, 0.5, np.pi/4])
# xgoal= np.array([grid_shape[0]-0.5, grid_shape[0]-0.5])
x0=np.array([mud_margin/2, mud_margin/2, np.pi/4])
xgoal= np.array([grid_shape[0]-mud_margin/2, grid_shape[0]-mud_margin/2])
max_speed = 3.0
max_steps = 150 # 200

default_mppi_params = dict(
    # Task specification
    dt=cfg.dt,
    x0=x0,
    xgoal=xgoal,
    timesteps=cfg.num_steps,
    u_seq0=u_seq0,

    # For risk-aware min time planning
    goal_tolerance=0.5,
    v_post_rollout=0.01, # 0.01,
    cvar_alpha=1.0, # use the mean if cvar_alpha=1.0

    # Hyper parameters
    lambda_weight=1.0,
    num_opt=1, # how many steps in each solve() function call

    # Control and sample specification
    u_std=np.array([3.0, 2.0]),
    vrange=np.array([0, max_speed]), 
    wrange=np.array([-np.pi, np.pi]),

    # Flags for using deterministic dynamics based on cvar
    use_det_dynamics=False,

    # Flag for using nominal rollouts but with risk-speed adjusted time cost
    use_nom_dynamics_with_speed_map=False,
)

# ------------- Variables to iterate ------------
grass_density_list = [0.2, 0.5, 0.8]
envs_per_density = 10
trials_per_env = 10
# alpha_list = np.linspace(1.0, 0.2, 5).tolist()
alpha_list = [1.0, 0.8, 0.6, 0.4, 0.2]
method_list = ['noisy_dyn','risk_dyn','nom_dyn_risk_cost']

# %%
filename = "exp_log_{}_margin_{}_env_{}_numtrial{}.pickle".format(time.strftime("%Y%m%d-%H%M"),
                                                        mud_margin,
                                                        envs_per_density,
                                                        trials_per_env)

benchmark_start_t = time.time()
logger = run_trials(cfg, max_speed, max_steps, grid_shape, mud_margin, res, num_pmf_bins, bin_values, bin_values_bounds, default_mppi_params,
               grass_density_list, envs_per_density, trials_per_env, alpha_list, method_list)
benchmark_duration = time.time() - benchmark_start_t
print('Benchmark took {:.2f}s'.format(benchmark_duration))

# Save the trials to
with open(filename, 'wb') as fh:
  pickle.dump(dict(
    # Main exp logger
    logger=logger,
    # Other configs
    cfg=cfg, 
    max_speed=max_speed, 
    max_steps=max_steps, 
    grid_shape=grid_shape, 
    mud_margin=mud_margin, 
    res=res, 
    num_pmf_bins=num_pmf_bins, 
    bin_values=bin_values, 
    bin_values_bounds=bin_values_bounds, 
    default_mppi_params=default_mppi_params,
    grass_density_list=grass_density_list, 
    envs_per_density=envs_per_density, 
    trials_per_env=trials_per_env, 
    alpha_list=alpha_list, 
    method_list=method_list,
    # Distributions
    pmf_bounds=pmf_bounds,
    bush_weights=bush_weights,
    bush_means=bush_means,
    bush_std=bush_std,
    dirt_weights=dirt_weights,
    dirt_means=dirt_means,
    dirt_std=dirt_std,
    ), file=fh
  )

print('Save to {}'.format(filename))
# Out:
#  grass_density=0.2 (1/3), sem_map(1/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# /home/jeremy/sara/phoenix-r1/venv/lib/python3.8/site-packages/numba/cuda/dispatcher.py:488: NumbaPerformanceWarning: Grid size 1 will likely result in GPU under-utilization due to low occupancy.
#   warn(NumbaPerformanceWarning(msg))
# 10 map realizations took 28.86s (2.89s on avg)
#  grass_density=0.2 (1/3), sem_map(1/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 31.82s (3.18s on avg)
#  grass_density=0.2 (1/3), sem_map(1/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 31.91s (3.19s on avg)
#  grass_density=0.2 (1/3), sem_map(1/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 30.56s (3.06s on avg)
#  grass_density=0.2 (1/3), sem_map(1/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 30.77s (3.08s on avg)
#  grass_density=0.2 (1/3), sem_map(1/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# /home/jeremy/sara/phoenix-r1/venv/lib/python3.8/site-packages/numba/cuda/dispatcher.py:488: NumbaPerformanceWarning: Grid size 1 will likely result in GPU under-utilization due to low occupancy.
#   warn(NumbaPerformanceWarning(msg))
# 10 map realizations took 5.39s (0.54s on avg)
#  grass_density=0.2 (1/3), sem_map(1/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 4.86s (0.49s on avg)
#  grass_density=0.2 (1/3), sem_map(1/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 4.45s (0.44s on avg)
#  grass_density=0.2 (1/3), sem_map(1/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.19s (0.42s on avg)
#  grass_density=0.2 (1/3), sem_map(1/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.22s (0.42s on avg)
#  grass_density=0.2 (1/3), sem_map(1/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.73s (0.47s on avg)
#  grass_density=0.2 (1/3), sem_map(1/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.61s (0.46s on avg)
#  grass_density=0.2 (1/3), sem_map(1/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.60s (0.46s on avg)
#  grass_density=0.2 (1/3), sem_map(1/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.51s (0.45s on avg)
#  grass_density=0.2 (1/3), sem_map(1/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.53s (0.45s on avg)
#  grass_density=0.2 (1/3), sem_map(2/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 24.01s (2.40s on avg)
#  grass_density=0.2 (1/3), sem_map(2/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 26.91s (2.69s on avg)
#  grass_density=0.2 (1/3), sem_map(2/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 28.43s (2.84s on avg)
#  grass_density=0.2 (1/3), sem_map(2/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 28.99s (2.90s on avg)
#  grass_density=0.2 (1/3), sem_map(2/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 28.52s (2.85s on avg)
#  grass_density=0.2 (1/3), sem_map(2/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.33s (0.53s on avg)
#  grass_density=0.2 (1/3), sem_map(2/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 4.37s (0.44s on avg)
#  grass_density=0.2 (1/3), sem_map(2/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 4.34s (0.43s on avg)
#  grass_density=0.2 (1/3), sem_map(2/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 3.96s (0.40s on avg)
#  grass_density=0.2 (1/3), sem_map(2/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 3.97s (0.40s on avg)
#  grass_density=0.2 (1/3), sem_map(2/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.45s (0.45s on avg)
#  grass_density=0.2 (1/3), sem_map(2/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.26s (0.43s on avg)
#  grass_density=0.2 (1/3), sem_map(2/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.00s (0.40s on avg)
#  grass_density=0.2 (1/3), sem_map(2/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.18s (0.42s on avg)
#  grass_density=0.2 (1/3), sem_map(2/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.36s (0.44s on avg)
#  grass_density=0.2 (1/3), sem_map(3/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 23.96s (2.40s on avg)
#  grass_density=0.2 (1/3), sem_map(3/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 28.94s (2.89s on avg)
#  grass_density=0.2 (1/3), sem_map(3/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 29.40s (2.94s on avg)
#  grass_density=0.2 (1/3), sem_map(3/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 30.01s (3.00s on avg)
#  grass_density=0.2 (1/3), sem_map(3/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 28.86s (2.89s on avg)
#  grass_density=0.2 (1/3), sem_map(3/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.09s (0.51s on avg)
#  grass_density=0.2 (1/3), sem_map(3/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 4.25s (0.42s on avg)
#  grass_density=0.2 (1/3), sem_map(3/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 3.90s (0.39s on avg)
#  grass_density=0.2 (1/3), sem_map(3/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 3.53s (0.35s on avg)
#  grass_density=0.2 (1/3), sem_map(3/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 3.55s (0.35s on avg)
#  grass_density=0.2 (1/3), sem_map(3/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.74s (0.47s on avg)
#  grass_density=0.2 (1/3), sem_map(3/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.55s (0.46s on avg)
#  grass_density=0.2 (1/3), sem_map(3/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.08s (0.41s on avg)
#  grass_density=0.2 (1/3), sem_map(3/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.19s (0.42s on avg)
#  grass_density=0.2 (1/3), sem_map(3/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 3.68s (0.37s on avg)
#  grass_density=0.2 (1/3), sem_map(4/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 23.50s (2.35s on avg)
#  grass_density=0.2 (1/3), sem_map(4/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 27.93s (2.79s on avg)
#  grass_density=0.2 (1/3), sem_map(4/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 28.65s (2.87s on avg)
#  grass_density=0.2 (1/3), sem_map(4/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 28.33s (2.83s on avg)
#  grass_density=0.2 (1/3), sem_map(4/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 29.22s (2.92s on avg)
#  grass_density=0.2 (1/3), sem_map(4/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.24s (0.52s on avg)
#  grass_density=0.2 (1/3), sem_map(4/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 4.60s (0.46s on avg)
#  grass_density=0.2 (1/3), sem_map(4/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 4.41s (0.44s on avg)
#  grass_density=0.2 (1/3), sem_map(4/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 3.81s (0.38s on avg)
#  grass_density=0.2 (1/3), sem_map(4/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 3.80s (0.38s on avg)
#  grass_density=0.2 (1/3), sem_map(4/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.86s (0.49s on avg)
#  grass_density=0.2 (1/3), sem_map(4/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.66s (0.47s on avg)
#  grass_density=0.2 (1/3), sem_map(4/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.17s (0.42s on avg)
#  grass_density=0.2 (1/3), sem_map(4/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 3.69s (0.37s on avg)
#  grass_density=0.2 (1/3), sem_map(4/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.19s (0.42s on avg)
#  grass_density=0.2 (1/3), sem_map(5/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 24.99s (2.50s on avg)
#  grass_density=0.2 (1/3), sem_map(5/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 31.04s (3.10s on avg)
#  grass_density=0.2 (1/3), sem_map(5/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 30.31s (3.03s on avg)
#  grass_density=0.2 (1/3), sem_map(5/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 29.50s (2.95s on avg)
#  grass_density=0.2 (1/3), sem_map(5/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 29.38s (2.94s on avg)
#  grass_density=0.2 (1/3), sem_map(5/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.37s (0.54s on avg)
#  grass_density=0.2 (1/3), sem_map(5/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 4.80s (0.48s on avg)
#  grass_density=0.2 (1/3), sem_map(5/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 4.44s (0.44s on avg)
#  grass_density=0.2 (1/3), sem_map(5/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 3.98s (0.40s on avg)
#  grass_density=0.2 (1/3), sem_map(5/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 3.98s (0.40s on avg)
#  grass_density=0.2 (1/3), sem_map(5/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.62s (0.46s on avg)
#  grass_density=0.2 (1/3), sem_map(5/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.33s (0.43s on avg)
#  grass_density=0.2 (1/3), sem_map(5/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.31s (0.43s on avg)
#  grass_density=0.2 (1/3), sem_map(5/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 3.95s (0.39s on avg)
#  grass_density=0.2 (1/3), sem_map(5/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.39s (0.44s on avg)
#  grass_density=0.2 (1/3), sem_map(6/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 24.08s (2.41s on avg)
#  grass_density=0.2 (1/3), sem_map(6/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 31.33s (3.13s on avg)
#  grass_density=0.2 (1/3), sem_map(6/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 31.18s (3.12s on avg)
#  grass_density=0.2 (1/3), sem_map(6/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 29.67s (2.97s on avg)
#  grass_density=0.2 (1/3), sem_map(6/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 28.49s (2.85s on avg)
#  grass_density=0.2 (1/3), sem_map(6/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.37s (0.54s on avg)
#  grass_density=0.2 (1/3), sem_map(6/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.07s (0.51s on avg)
#  grass_density=0.2 (1/3), sem_map(6/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 5.28s (0.53s on avg)
#  grass_density=0.2 (1/3), sem_map(6/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.19s (0.42s on avg)
#  grass_density=0.2 (1/3), sem_map(6/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.18s (0.42s on avg)
#  grass_density=0.2 (1/3), sem_map(6/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.60s (0.46s on avg)
#  grass_density=0.2 (1/3), sem_map(6/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.53s (0.45s on avg)
#  grass_density=0.2 (1/3), sem_map(6/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.53s (0.45s on avg)
#  grass_density=0.2 (1/3), sem_map(6/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.52s (0.45s on avg)
#  grass_density=0.2 (1/3), sem_map(6/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.47s (0.45s on avg)
#  grass_density=0.2 (1/3), sem_map(7/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 24.54s (2.45s on avg)
#  grass_density=0.2 (1/3), sem_map(7/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 30.03s (3.00s on avg)
#  grass_density=0.2 (1/3), sem_map(7/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 29.84s (2.98s on avg)
#  grass_density=0.2 (1/3), sem_map(7/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 28.83s (2.88s on avg)
#  grass_density=0.2 (1/3), sem_map(7/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 28.25s (2.82s on avg)
#  grass_density=0.2 (1/3), sem_map(7/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.46s (0.55s on avg)
#  grass_density=0.2 (1/3), sem_map(7/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 4.25s (0.43s on avg)
#  grass_density=0.2 (1/3), sem_map(7/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 4.42s (0.44s on avg)
#  grass_density=0.2 (1/3), sem_map(7/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 3.84s (0.38s on avg)
#  grass_density=0.2 (1/3), sem_map(7/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 3.84s (0.38s on avg)
#  grass_density=0.2 (1/3), sem_map(7/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.83s (0.48s on avg)
#  grass_density=0.2 (1/3), sem_map(7/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.59s (0.46s on avg)
#  grass_density=0.2 (1/3), sem_map(7/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.44s (0.44s on avg)
#  grass_density=0.2 (1/3), sem_map(7/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.31s (0.43s on avg)
#  grass_density=0.2 (1/3), sem_map(7/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.33s (0.43s on avg)
#  grass_density=0.2 (1/3), sem_map(8/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 22.94s (2.29s on avg)
#  grass_density=0.2 (1/3), sem_map(8/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 28.15s (2.82s on avg)
#  grass_density=0.2 (1/3), sem_map(8/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 26.80s (2.68s on avg)
#  grass_density=0.2 (1/3), sem_map(8/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 29.44s (2.94s on avg)
#  grass_density=0.2 (1/3), sem_map(8/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 28.47s (2.85s on avg)
#  grass_density=0.2 (1/3), sem_map(8/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.48s (0.55s on avg)
#  grass_density=0.2 (1/3), sem_map(8/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 4.78s (0.48s on avg)
#  grass_density=0.2 (1/3), sem_map(8/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 4.38s (0.44s on avg)
#  grass_density=0.2 (1/3), sem_map(8/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.03s (0.40s on avg)
#  grass_density=0.2 (1/3), sem_map(8/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.04s (0.40s on avg)
#  grass_density=0.2 (1/3), sem_map(8/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.40s (0.44s on avg)
#  grass_density=0.2 (1/3), sem_map(8/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.46s (0.45s on avg)
#  grass_density=0.2 (1/3), sem_map(8/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.13s (0.41s on avg)
#  grass_density=0.2 (1/3), sem_map(8/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.40s (0.44s on avg)
#  grass_density=0.2 (1/3), sem_map(8/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.28s (0.43s on avg)
#  grass_density=0.2 (1/3), sem_map(9/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 24.24s (2.42s on avg)
#  grass_density=0.2 (1/3), sem_map(9/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 28.88s (2.89s on avg)
#  grass_density=0.2 (1/3), sem_map(9/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 32.12s (3.21s on avg)
#  grass_density=0.2 (1/3), sem_map(9/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 32.07s (3.21s on avg)
#  grass_density=0.2 (1/3), sem_map(9/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 30.53s (3.05s on avg)
#  grass_density=0.2 (1/3), sem_map(9/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.56s (0.56s on avg)
#  grass_density=0.2 (1/3), sem_map(9/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.18s (0.52s on avg)
#  grass_density=0.2 (1/3), sem_map(9/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 4.84s (0.48s on avg)
#  grass_density=0.2 (1/3), sem_map(9/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.34s (0.43s on avg)
#  grass_density=0.2 (1/3), sem_map(9/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.45s (0.45s on avg)
#  grass_density=0.2 (1/3), sem_map(9/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.66s (0.47s on avg)
#  grass_density=0.2 (1/3), sem_map(9/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.36s (0.44s on avg)
#  grass_density=0.2 (1/3), sem_map(9/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.24s (0.42s on avg)
#  grass_density=0.2 (1/3), sem_map(9/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.61s (0.46s on avg)
#  grass_density=0.2 (1/3), sem_map(9/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.12s (0.41s on avg)
#  grass_density=0.2 (1/3), sem_map(10/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 25.19s (2.52s on avg)
#  grass_density=0.2 (1/3), sem_map(10/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 30.07s (3.01s on avg)
#  grass_density=0.2 (1/3), sem_map(10/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 31.29s (3.13s on avg)
#  grass_density=0.2 (1/3), sem_map(10/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 29.63s (2.96s on avg)
#  grass_density=0.2 (1/3), sem_map(10/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 31.02s (3.10s on avg)
#  grass_density=0.2 (1/3), sem_map(10/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.41s (0.54s on avg)
#  grass_density=0.2 (1/3), sem_map(10/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 4.92s (0.49s on avg)
#  grass_density=0.2 (1/3), sem_map(10/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 4.87s (0.49s on avg)
#  grass_density=0.2 (1/3), sem_map(10/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.64s (0.46s on avg)
#  grass_density=0.2 (1/3), sem_map(10/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.42s (0.44s on avg)
#  grass_density=0.2 (1/3), sem_map(10/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.46s (0.45s on avg)
#  grass_density=0.2 (1/3), sem_map(10/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.80s (0.48s on avg)
#  grass_density=0.2 (1/3), sem_map(10/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.44s (0.44s on avg)
#  grass_density=0.2 (1/3), sem_map(10/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.39s (0.44s on avg)
#  grass_density=0.2 (1/3), sem_map(10/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.23s (0.42s on avg)
#  grass_density=0.5 (2/3), sem_map(1/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 31.00s (3.10s on avg)
#  grass_density=0.5 (2/3), sem_map(1/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 35.67s (3.57s on avg)
#  grass_density=0.5 (2/3), sem_map(1/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 36.04s (3.60s on avg)
#  grass_density=0.5 (2/3), sem_map(1/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 39.81s (3.98s on avg)
#  grass_density=0.5 (2/3), sem_map(1/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 42.64s (4.26s on avg)
#  grass_density=0.5 (2/3), sem_map(1/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.49s (0.55s on avg)
#  grass_density=0.5 (2/3), sem_map(1/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.36s (0.54s on avg)
#  grass_density=0.5 (2/3), sem_map(1/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 4.73s (0.47s on avg)
#  grass_density=0.5 (2/3), sem_map(1/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 5.00s (0.50s on avg)
#  grass_density=0.5 (2/3), sem_map(1/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.97s (0.50s on avg)
#  grass_density=0.5 (2/3), sem_map(1/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.82s (0.48s on avg)
#  grass_density=0.5 (2/3), sem_map(1/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.71s (0.47s on avg)
#  grass_density=0.5 (2/3), sem_map(1/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.91s (0.49s on avg)
#  grass_density=0.5 (2/3), sem_map(1/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.93s (0.49s on avg)
#  grass_density=0.5 (2/3), sem_map(1/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.83s (0.48s on avg)
#  grass_density=0.5 (2/3), sem_map(2/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 27.95s (2.80s on avg)
#  grass_density=0.5 (2/3), sem_map(2/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 31.56s (3.16s on avg)
#  grass_density=0.5 (2/3), sem_map(2/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 34.33s (3.43s on avg)
#  grass_density=0.5 (2/3), sem_map(2/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 32.71s (3.27s on avg)
#  grass_density=0.5 (2/3), sem_map(2/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 33.59s (3.36s on avg)
#  grass_density=0.5 (2/3), sem_map(2/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.52s (0.55s on avg)
#  grass_density=0.5 (2/3), sem_map(2/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.16s (0.52s on avg)
#  grass_density=0.5 (2/3), sem_map(2/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 4.64s (0.46s on avg)
#  grass_density=0.5 (2/3), sem_map(2/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.58s (0.46s on avg)
#  grass_density=0.5 (2/3), sem_map(2/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.57s (0.46s on avg)
#  grass_density=0.5 (2/3), sem_map(2/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.98s (0.50s on avg)
#  grass_density=0.5 (2/3), sem_map(2/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 5.02s (0.50s on avg)
#  grass_density=0.5 (2/3), sem_map(2/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.82s (0.48s on avg)
#  grass_density=0.5 (2/3), sem_map(2/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.66s (0.47s on avg)
#  grass_density=0.5 (2/3), sem_map(2/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.71s (0.47s on avg)
#  grass_density=0.5 (2/3), sem_map(3/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 31.36s (3.14s on avg)
#  grass_density=0.5 (2/3), sem_map(3/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 39.36s (3.94s on avg)
#  grass_density=0.5 (2/3), sem_map(3/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 37.31s (3.73s on avg)
#  grass_density=0.5 (2/3), sem_map(3/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 40.85s (4.09s on avg)
#  grass_density=0.5 (2/3), sem_map(3/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 41.77s (4.18s on avg)
#  grass_density=0.5 (2/3), sem_map(3/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.46s (0.55s on avg)
#  grass_density=0.5 (2/3), sem_map(3/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.06s (0.51s on avg)
#  grass_density=0.5 (2/3), sem_map(3/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 5.05s (0.51s on avg)
#  grass_density=0.5 (2/3), sem_map(3/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.84s (0.48s on avg)
#  grass_density=0.5 (2/3), sem_map(3/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.81s (0.48s on avg)
#  grass_density=0.5 (2/3), sem_map(3/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.97s (0.50s on avg)
#  grass_density=0.5 (2/3), sem_map(3/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.84s (0.48s on avg)
#  grass_density=0.5 (2/3), sem_map(3/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.75s (0.48s on avg)
#  grass_density=0.5 (2/3), sem_map(3/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.92s (0.49s on avg)
#  grass_density=0.5 (2/3), sem_map(3/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.83s (0.48s on avg)
#  grass_density=0.5 (2/3), sem_map(4/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 24.15s (2.42s on avg)
#  grass_density=0.5 (2/3), sem_map(4/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 30.28s (3.03s on avg)
#  grass_density=0.5 (2/3), sem_map(4/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 31.80s (3.18s on avg)
#  grass_density=0.5 (2/3), sem_map(4/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 31.07s (3.11s on avg)
#  grass_density=0.5 (2/3), sem_map(4/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 29.43s (2.94s on avg)
#  grass_density=0.5 (2/3), sem_map(4/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.42s (0.54s on avg)
#  grass_density=0.5 (2/3), sem_map(4/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 4.90s (0.49s on avg)
#  grass_density=0.5 (2/3), sem_map(4/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 4.56s (0.46s on avg)
#  grass_density=0.5 (2/3), sem_map(4/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.16s (0.42s on avg)
#  grass_density=0.5 (2/3), sem_map(4/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.14s (0.41s on avg)
#  grass_density=0.5 (2/3), sem_map(4/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.70s (0.47s on avg)
#  grass_density=0.5 (2/3), sem_map(4/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.74s (0.47s on avg)
#  grass_density=0.5 (2/3), sem_map(4/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.30s (0.43s on avg)
#  grass_density=0.5 (2/3), sem_map(4/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.86s (0.49s on avg)
#  grass_density=0.5 (2/3), sem_map(4/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.39s (0.44s on avg)
#  grass_density=0.5 (2/3), sem_map(5/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 26.70s (2.67s on avg)
#  grass_density=0.5 (2/3), sem_map(5/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 33.18s (3.32s on avg)
#  grass_density=0.5 (2/3), sem_map(5/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 33.51s (3.35s on avg)
#  grass_density=0.5 (2/3), sem_map(5/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 34.40s (3.44s on avg)
#  grass_density=0.5 (2/3), sem_map(5/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 33.88s (3.39s on avg)
#  grass_density=0.5 (2/3), sem_map(5/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.46s (0.55s on avg)
#  grass_density=0.5 (2/3), sem_map(5/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.33s (0.53s on avg)
#  grass_density=0.5 (2/3), sem_map(5/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 4.80s (0.48s on avg)
#  grass_density=0.5 (2/3), sem_map(5/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.24s (0.42s on avg)
#  grass_density=0.5 (2/3), sem_map(5/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.22s (0.42s on avg)
#  grass_density=0.5 (2/3), sem_map(5/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.64s (0.46s on avg)
#  grass_density=0.5 (2/3), sem_map(5/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.69s (0.47s on avg)
#  grass_density=0.5 (2/3), sem_map(5/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.71s (0.47s on avg)
#  grass_density=0.5 (2/3), sem_map(5/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.90s (0.49s on avg)
#  grass_density=0.5 (2/3), sem_map(5/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.73s (0.47s on avg)
#  grass_density=0.5 (2/3), sem_map(6/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 24.23s (2.42s on avg)
#  grass_density=0.5 (2/3), sem_map(6/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 28.13s (2.81s on avg)
#  grass_density=0.5 (2/3), sem_map(6/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 33.06s (3.31s on avg)
#  grass_density=0.5 (2/3), sem_map(6/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 42.09s (4.21s on avg)
#  grass_density=0.5 (2/3), sem_map(6/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 42.19s (4.22s on avg)
#  grass_density=0.5 (2/3), sem_map(6/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.43s (0.54s on avg)
#  grass_density=0.5 (2/3), sem_map(6/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.07s (0.51s on avg)
#  grass_density=0.5 (2/3), sem_map(6/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 5.13s (0.51s on avg)
#  grass_density=0.5 (2/3), sem_map(6/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.59s (0.46s on avg)
#  grass_density=0.5 (2/3), sem_map(6/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.58s (0.46s on avg)
#  grass_density=0.5 (2/3), sem_map(6/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.48s (0.45s on avg)
#  grass_density=0.5 (2/3), sem_map(6/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.64s (0.46s on avg)
#  grass_density=0.5 (2/3), sem_map(6/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.41s (0.44s on avg)
#  grass_density=0.5 (2/3), sem_map(6/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.46s (0.45s on avg)
#  grass_density=0.5 (2/3), sem_map(6/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.86s (0.49s on avg)
#  grass_density=0.5 (2/3), sem_map(7/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 27.53s (2.75s on avg)
#  grass_density=0.5 (2/3), sem_map(7/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 33.74s (3.37s on avg)
#  grass_density=0.5 (2/3), sem_map(7/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 32.70s (3.27s on avg)
#  grass_density=0.5 (2/3), sem_map(7/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 33.42s (3.34s on avg)
#  grass_density=0.5 (2/3), sem_map(7/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 34.18s (3.42s on avg)
#  grass_density=0.5 (2/3), sem_map(7/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.41s (0.54s on avg)
#  grass_density=0.5 (2/3), sem_map(7/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.32s (0.53s on avg)
#  grass_density=0.5 (2/3), sem_map(7/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 5.06s (0.51s on avg)
#  grass_density=0.5 (2/3), sem_map(7/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.50s (0.45s on avg)
#  grass_density=0.5 (2/3), sem_map(7/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.56s (0.46s on avg)
#  grass_density=0.5 (2/3), sem_map(7/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.87s (0.49s on avg)
#  grass_density=0.5 (2/3), sem_map(7/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.80s (0.48s on avg)
#  grass_density=0.5 (2/3), sem_map(7/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.80s (0.48s on avg)
#  grass_density=0.5 (2/3), sem_map(7/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.52s (0.45s on avg)
#  grass_density=0.5 (2/3), sem_map(7/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.90s (0.49s on avg)
#  grass_density=0.5 (2/3), sem_map(8/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 31.28s (3.13s on avg)
#  grass_density=0.5 (2/3), sem_map(8/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 36.09s (3.61s on avg)
#  grass_density=0.5 (2/3), sem_map(8/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 35.62s (3.56s on avg)
#  grass_density=0.5 (2/3), sem_map(8/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 36.37s (3.64s on avg)
#  grass_density=0.5 (2/3), sem_map(8/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 36.52s (3.65s on avg)
#  grass_density=0.5 (2/3), sem_map(8/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.60s (0.56s on avg)
#  grass_density=0.5 (2/3), sem_map(8/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.44s (0.54s on avg)
#  grass_density=0.5 (2/3), sem_map(8/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 5.19s (0.52s on avg)
#  grass_density=0.5 (2/3), sem_map(8/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.92s (0.49s on avg)
#  grass_density=0.5 (2/3), sem_map(8/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.97s (0.50s on avg)
#  grass_density=0.5 (2/3), sem_map(8/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.92s (0.49s on avg)
#  grass_density=0.5 (2/3), sem_map(8/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.78s (0.48s on avg)
#  grass_density=0.5 (2/3), sem_map(8/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.92s (0.49s on avg)
#  grass_density=0.5 (2/3), sem_map(8/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.75s (0.47s on avg)
#  grass_density=0.5 (2/3), sem_map(8/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.99s (0.50s on avg)
#  grass_density=0.5 (2/3), sem_map(9/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 27.69s (2.77s on avg)
#  grass_density=0.5 (2/3), sem_map(9/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 35.24s (3.52s on avg)
#  grass_density=0.5 (2/3), sem_map(9/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 38.52s (3.85s on avg)
#  grass_density=0.5 (2/3), sem_map(9/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 37.12s (3.71s on avg)
#  grass_density=0.5 (2/3), sem_map(9/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 56.79s (5.68s on avg)
#  grass_density=0.5 (2/3), sem_map(9/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.31s (0.53s on avg)
#  grass_density=0.5 (2/3), sem_map(9/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 4.82s (0.48s on avg)
#  grass_density=0.5 (2/3), sem_map(9/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 7.26s (0.73s on avg)
#  grass_density=0.5 (2/3), sem_map(9/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 17.45s (1.74s on avg)
#  grass_density=0.5 (2/3), sem_map(9/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 6.91s (0.69s on avg)
#  grass_density=0.5 (2/3), sem_map(9/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.66s (0.47s on avg)
#  grass_density=0.5 (2/3), sem_map(9/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.67s (0.47s on avg)
#  grass_density=0.5 (2/3), sem_map(9/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.39s (0.44s on avg)
#  grass_density=0.5 (2/3), sem_map(9/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.37s (0.44s on avg)
#  grass_density=0.5 (2/3), sem_map(9/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 5.06s (0.51s on avg)
#  grass_density=0.5 (2/3), sem_map(10/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 31.68s (3.17s on avg)
#  grass_density=0.5 (2/3), sem_map(10/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 42.90s (4.29s on avg)
#  grass_density=0.5 (2/3), sem_map(10/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 42.18s (4.22s on avg)
#  grass_density=0.5 (2/3), sem_map(10/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 31.68s (3.17s on avg)
#  grass_density=0.5 (2/3), sem_map(10/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 34.35s (3.44s on avg)
#  grass_density=0.5 (2/3), sem_map(10/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.46s (0.55s on avg)
#  grass_density=0.5 (2/3), sem_map(10/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.04s (0.50s on avg)
#  grass_density=0.5 (2/3), sem_map(10/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 4.96s (0.50s on avg)
#  grass_density=0.5 (2/3), sem_map(10/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.59s (0.46s on avg)
#  grass_density=0.5 (2/3), sem_map(10/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.56s (0.46s on avg)
#  grass_density=0.5 (2/3), sem_map(10/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.86s (0.49s on avg)
#  grass_density=0.5 (2/3), sem_map(10/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.65s (0.47s on avg)
#  grass_density=0.5 (2/3), sem_map(10/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.86s (0.49s on avg)
#  grass_density=0.5 (2/3), sem_map(10/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.66s (0.47s on avg)
#  grass_density=0.5 (2/3), sem_map(10/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.49s (0.45s on avg)
#  grass_density=0.8 (3/3), sem_map(1/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 32.56s (3.26s on avg)
#  grass_density=0.8 (3/3), sem_map(1/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 38.49s (3.85s on avg)
#  grass_density=0.8 (3/3), sem_map(1/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 40.01s (4.00s on avg)
#  grass_density=0.8 (3/3), sem_map(1/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 39.06s (3.91s on avg)
#  grass_density=0.8 (3/3), sem_map(1/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 39.43s (3.94s on avg)
#  grass_density=0.8 (3/3), sem_map(1/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.51s (0.55s on avg)
#  grass_density=0.8 (3/3), sem_map(1/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.44s (0.54s on avg)
#  grass_density=0.8 (3/3), sem_map(1/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 4.85s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(1/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.63s (0.46s on avg)
#  grass_density=0.8 (3/3), sem_map(1/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.60s (0.46s on avg)
#  grass_density=0.8 (3/3), sem_map(1/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.85s (0.48s on avg)
#  grass_density=0.8 (3/3), sem_map(1/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.88s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(1/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.81s (0.48s on avg)
#  grass_density=0.8 (3/3), sem_map(1/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.88s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(1/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.83s (0.48s on avg)
#  grass_density=0.8 (3/3), sem_map(2/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 33.42s (3.34s on avg)
#  grass_density=0.8 (3/3), sem_map(2/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 41.04s (4.10s on avg)
#  grass_density=0.8 (3/3), sem_map(2/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 37.64s (3.76s on avg)
#  grass_density=0.8 (3/3), sem_map(2/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 44.55s (4.45s on avg)
#  grass_density=0.8 (3/3), sem_map(2/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 38.15s (3.81s on avg)
#  grass_density=0.8 (3/3), sem_map(2/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.44s (0.54s on avg)
#  grass_density=0.8 (3/3), sem_map(2/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.27s (0.53s on avg)
#  grass_density=0.8 (3/3), sem_map(2/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 5.16s (0.52s on avg)
#  grass_density=0.8 (3/3), sem_map(2/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.92s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(2/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.94s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(2/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.78s (0.48s on avg)
#  grass_density=0.8 (3/3), sem_map(2/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.86s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(2/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.75s (0.47s on avg)
#  grass_density=0.8 (3/3), sem_map(2/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.69s (0.47s on avg)
#  grass_density=0.8 (3/3), sem_map(2/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.72s (0.47s on avg)
#  grass_density=0.8 (3/3), sem_map(3/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 39.10s (3.91s on avg)
#  grass_density=0.8 (3/3), sem_map(3/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 42.97s (4.30s on avg)
#  grass_density=0.8 (3/3), sem_map(3/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 41.94s (4.19s on avg)
#  grass_density=0.8 (3/3), sem_map(3/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 45.05s (4.50s on avg)
#  grass_density=0.8 (3/3), sem_map(3/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 45.88s (4.59s on avg)
#  grass_density=0.8 (3/3), sem_map(3/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.50s (0.55s on avg)
#  grass_density=0.8 (3/3), sem_map(3/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.47s (0.55s on avg)
#  grass_density=0.8 (3/3), sem_map(3/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 5.35s (0.54s on avg)
#  grass_density=0.8 (3/3), sem_map(3/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 5.06s (0.51s on avg)
#  grass_density=0.8 (3/3), sem_map(3/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 5.08s (0.51s on avg)
#  grass_density=0.8 (3/3), sem_map(3/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.91s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(3/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.88s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(3/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.85s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(3/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.83s (0.48s on avg)
#  grass_density=0.8 (3/3), sem_map(3/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.78s (0.48s on avg)
#  grass_density=0.8 (3/3), sem_map(4/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 31.59s (3.16s on avg)
#  grass_density=0.8 (3/3), sem_map(4/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 37.14s (3.71s on avg)
#  grass_density=0.8 (3/3), sem_map(4/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 38.13s (3.81s on avg)
#  grass_density=0.8 (3/3), sem_map(4/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 38.35s (3.84s on avg)
#  grass_density=0.8 (3/3), sem_map(4/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 38.23s (3.82s on avg)
#  grass_density=0.8 (3/3), sem_map(4/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.47s (0.55s on avg)
#  grass_density=0.8 (3/3), sem_map(4/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.45s (0.54s on avg)
#  grass_density=0.8 (3/3), sem_map(4/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 4.71s (0.47s on avg)
#  grass_density=0.8 (3/3), sem_map(4/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.93s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(4/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 5.00s (0.50s on avg)
#  grass_density=0.8 (3/3), sem_map(4/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.93s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(4/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.86s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(4/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.91s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(4/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.94s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(4/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 5.02s (0.50s on avg)
#  grass_density=0.8 (3/3), sem_map(5/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 33.62s (3.36s on avg)
#  grass_density=0.8 (3/3), sem_map(5/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 39.81s (3.98s on avg)
#  grass_density=0.8 (3/3), sem_map(5/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 39.72s (3.97s on avg)
#  grass_density=0.8 (3/3), sem_map(5/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 39.57s (3.96s on avg)
#  grass_density=0.8 (3/3), sem_map(5/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 43.61s (4.36s on avg)
#  grass_density=0.8 (3/3), sem_map(5/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.59s (0.56s on avg)
#  grass_density=0.8 (3/3), sem_map(5/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.42s (0.54s on avg)
#  grass_density=0.8 (3/3), sem_map(5/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 5.35s (0.53s on avg)
#  grass_density=0.8 (3/3), sem_map(5/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.94s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(5/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.97s (0.50s on avg)
#  grass_density=0.8 (3/3), sem_map(5/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.73s (0.47s on avg)
#  grass_density=0.8 (3/3), sem_map(5/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.94s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(5/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.86s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(5/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.81s (0.48s on avg)
#  grass_density=0.8 (3/3), sem_map(5/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.78s (0.48s on avg)
#  grass_density=0.8 (3/3), sem_map(6/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 30.40s (3.04s on avg)
#  grass_density=0.8 (3/3), sem_map(6/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 36.00s (3.60s on avg)
#  grass_density=0.8 (3/3), sem_map(6/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 37.94s (3.79s on avg)
#  grass_density=0.8 (3/3), sem_map(6/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 36.98s (3.70s on avg)
#  grass_density=0.8 (3/3), sem_map(6/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 37.34s (3.73s on avg)
#  grass_density=0.8 (3/3), sem_map(6/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.39s (0.54s on avg)
#  grass_density=0.8 (3/3), sem_map(6/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.34s (0.53s on avg)
#  grass_density=0.8 (3/3), sem_map(6/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 5.13s (0.51s on avg)
#  grass_density=0.8 (3/3), sem_map(6/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.76s (0.48s on avg)
#  grass_density=0.8 (3/3), sem_map(6/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.81s (0.48s on avg)
#  grass_density=0.8 (3/3), sem_map(6/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.91s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(6/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.88s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(6/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.88s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(6/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.93s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(6/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.90s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(7/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 31.17s (3.12s on avg)
#  grass_density=0.8 (3/3), sem_map(7/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 38.47s (3.85s on avg)
#  grass_density=0.8 (3/3), sem_map(7/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 38.51s (3.85s on avg)
#  grass_density=0.8 (3/3), sem_map(7/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 39.86s (3.99s on avg)
#  grass_density=0.8 (3/3), sem_map(7/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 41.56s (4.16s on avg)
#  grass_density=0.8 (3/3), sem_map(7/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.42s (0.54s on avg)
#  grass_density=0.8 (3/3), sem_map(7/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.17s (0.52s on avg)
#  grass_density=0.8 (3/3), sem_map(7/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 5.13s (0.51s on avg)
#  grass_density=0.8 (3/3), sem_map(7/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.86s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(7/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.89s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(7/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.91s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(7/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.90s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(7/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.89s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(7/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.68s (0.47s on avg)
#  grass_density=0.8 (3/3), sem_map(7/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.66s (0.47s on avg)
#  grass_density=0.8 (3/3), sem_map(8/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 28.85s (2.88s on avg)
#  grass_density=0.8 (3/3), sem_map(8/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 33.89s (3.39s on avg)
#  grass_density=0.8 (3/3), sem_map(8/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 33.99s (3.40s on avg)
#  grass_density=0.8 (3/3), sem_map(8/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 36.91s (3.69s on avg)
#  grass_density=0.8 (3/3), sem_map(8/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 35.38s (3.54s on avg)
#  grass_density=0.8 (3/3), sem_map(8/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.36s (0.54s on avg)
#  grass_density=0.8 (3/3), sem_map(8/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.05s (0.51s on avg)
#  grass_density=0.8 (3/3), sem_map(8/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 4.86s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(8/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.50s (0.45s on avg)
#  grass_density=0.8 (3/3), sem_map(8/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.47s (0.45s on avg)
#  grass_density=0.8 (3/3), sem_map(8/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.81s (0.48s on avg)
#  grass_density=0.8 (3/3), sem_map(8/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.80s (0.48s on avg)
#  grass_density=0.8 (3/3), sem_map(8/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.83s (0.48s on avg)
#  grass_density=0.8 (3/3), sem_map(8/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.88s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(8/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.72s (0.47s on avg)
#  grass_density=0.8 (3/3), sem_map(9/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 34.63s (3.46s on avg)
#  grass_density=0.8 (3/3), sem_map(9/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 42.23s (4.22s on avg)
#  grass_density=0.8 (3/3), sem_map(9/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 41.52s (4.15s on avg)
#  grass_density=0.8 (3/3), sem_map(9/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 43.54s (4.35s on avg)
#  grass_density=0.8 (3/3), sem_map(9/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 46.06s (4.61s on avg)
#  grass_density=0.8 (3/3), sem_map(9/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.41s (0.54s on avg)
#  grass_density=0.8 (3/3), sem_map(9/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.42s (0.54s on avg)
#  grass_density=0.8 (3/3), sem_map(9/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 4.69s (0.47s on avg)
#  grass_density=0.8 (3/3), sem_map(9/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.95s (0.50s on avg)
#  grass_density=0.8 (3/3), sem_map(9/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.96s (0.50s on avg)
#  grass_density=0.8 (3/3), sem_map(9/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.86s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(9/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.82s (0.48s on avg)
#  grass_density=0.8 (3/3), sem_map(9/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.80s (0.48s on avg)
#  grass_density=0.8 (3/3), sem_map(9/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.80s (0.48s on avg)
#  grass_density=0.8 (3/3), sem_map(9/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.84s (0.48s on avg)
#  grass_density=0.8 (3/3), sem_map(10/10), method=noisy_dyn(1/3), alpha=1.0(1/5)
# 10 map realizations took 31.77s (3.18s on avg)
#  grass_density=0.8 (3/3), sem_map(10/10), method=noisy_dyn(1/3), alpha=0.8(2/5)
# 10 map realizations took 38.51s (3.85s on avg)
#  grass_density=0.8 (3/3), sem_map(10/10), method=noisy_dyn(1/3), alpha=0.6(3/5)
# 10 map realizations took 38.35s (3.84s on avg)
#  grass_density=0.8 (3/3), sem_map(10/10), method=noisy_dyn(1/3), alpha=0.4(4/5)
# 10 map realizations took 39.70s (3.97s on avg)
#  grass_density=0.8 (3/3), sem_map(10/10), method=noisy_dyn(1/3), alpha=0.2(5/5)
# 10 map realizations took 40.11s (4.01s on avg)
#  grass_density=0.8 (3/3), sem_map(10/10), method=risk_dyn(2/3), alpha=1.0(1/5)
# 10 map realizations took 5.40s (0.54s on avg)
#  grass_density=0.8 (3/3), sem_map(10/10), method=risk_dyn(2/3), alpha=0.8(2/5)
# 10 map realizations took 5.43s (0.54s on avg)
#  grass_density=0.8 (3/3), sem_map(10/10), method=risk_dyn(2/3), alpha=0.6(3/5)
# 10 map realizations took 5.22s (0.52s on avg)
#  grass_density=0.8 (3/3), sem_map(10/10), method=risk_dyn(2/3), alpha=0.4(4/5)
# 10 map realizations took 4.95s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(10/10), method=risk_dyn(2/3), alpha=0.2(5/5)
# 10 map realizations took 4.91s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(10/10), method=nom_dyn_risk_cost(3/3), alpha=1.0(1/5)
# 10 map realizations took 4.63s (0.46s on avg)
#  grass_density=0.8 (3/3), sem_map(10/10), method=nom_dyn_risk_cost(3/3), alpha=0.8(2/5)
# 10 map realizations took 4.89s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(10/10), method=nom_dyn_risk_cost(3/3), alpha=0.6(3/5)
# 10 map realizations took 4.91s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(10/10), method=nom_dyn_risk_cost(3/3), alpha=0.4(4/5)
# 10 map realizations took 4.89s (0.49s on avg)
#  grass_density=0.8 (3/3), sem_map(10/10), method=nom_dyn_risk_cost(3/3), alpha=0.2(5/5)
# 10 map realizations took 4.74s (0.47s on avg)
# Benchmark took 6520.87s
# Save to exp_log_20220824-0155_margin_1_env_10_numtrial10.pickle

# %%
display(logger)

method2rgb = {
  'noisy_dyn': 'r',
  'risk_dyn': 'g',
  'nom_dyn_risk_cost': 'b'
}
method2label = {
  'noisy_dyn': 'Noisy Traction',
  'risk_dyn': r'CVaR($\alpha$) Traction',
  'nom_dyn_risk_cost': 'Risk-Adjusted Cost'
}
sorted_grass_density_list = sorted(grass_density_list)
sorted_alpha_list = sorted(alpha_list)
# Plot success rate vs. alpha for each method
fig, axes = plt.subplots(ncols=len(sorted_grass_density_list), sharey=True, figsize=(15, 5))
for density_i, grass_density in enumerate(sorted_grass_density_list):
  if len(sorted_grass_density_list)==1:
    ax=axes
  else:
    ax = axes[density_i]
  for method in method_list:
    success_rate = []
    for alpha in sorted_alpha_list:
      sub_logger = logger[(logger['grass_density']==grass_density) & (logger['method']==method) & (logger['alpha']==alpha)]
      success_rate.append(sub_logger['success'].sum()/len(sub_logger))
    success_rate = np.asarray(success_rate)
    ax.plot(sorted_alpha_list, success_rate, '-', color=method2rgb[method], label=method2label[method])
    ax.plot(sorted_alpha_list, success_rate, '.', color=method2rgb[method], markersize=15)
  ax.legend()
  ax.set_ylim([-0.1,1.1])
  if density_i==0:
    ax.set_ylabel('Success Rate')
  ax.set_xlabel(r'$\alpha$')
  ax.set_title('Grass Density={:.1f}%'.format(grass_density*100))

# Plot time-to-goal for successful trials for each alpha
fig, axes = plt.subplots(ncols=len(sorted_grass_density_list), sharey=True, figsize=(15, 5))
for density_i, grass_density in enumerate(sorted_grass_density_list):
  if len(sorted_grass_density_list)==1:
    ax=axes
  else:
    ax = axes[density_i]
  for method in method_list:
    t2g = []
    t2g_std = []
    for alpha in sorted_alpha_list:
      sub_logger = logger[logger['success'] & (logger['grass_density']==grass_density) & (logger['method']==method) & (logger['alpha']==alpha)]
      if len(sub_logger)>0:
        t2g.append(sub_logger['time_to_goal'].sum()/len(sub_logger))
        t2g_std.append(sub_logger['time_to_goal'].std())
      else:
        t2g.append(np.nan)
        t2g_std.append(np.nan)

        
    t2g = np.asarray(t2g)
    t2g_std = np.asarray(t2g_std)
    ax.plot(sorted_alpha_list, t2g, '-', color=method2rgb[method], label=method2label[method])
    ax.fill_between(sorted_alpha_list, t2g-t2g_std, t2g+t2g_std,
              alpha=0.15, edgecolor='none', facecolor=method2rgb[method])
    ax.plot(sorted_alpha_list, t2g, '.', color=method2rgb[method], markersize=15)
  ax.legend()
  if density_i==0:
    ax.set_ylabel('Time-To-Goal (s)')
  ax.set_xlabel(r'$\alpha$')
  ax.set_title('Grass Density={:.1f}%'.format(grass_density*100))
# Out:
#       time_to_goal  success  grass_density  grass_density_index  \
# 0             11.8     True            0.2                    0
# 1             10.3     True            0.2                    0
# 2              9.5     True            0.2                    0
# 3             10.3     True            0.2                    0
# 4             12.2     True            0.2                    0
# ...            ...      ...            ...                  ...
# 4495           NaN    False            0.8                    2
# 4496          10.3     True            0.8                    2
# 4497           NaN    False            0.8                    2
# 4498           NaN    False            0.8                    2
# 4499           NaN    False            0.8                    2
#
#       sem_map_index             method  alpha  map_sample_index
# 0                 0          noisy_dyn    1.0                 0
# 1                 0          noisy_dyn    1.0                 1
# 2                 0          noisy_dyn    1.0                 2
# 3                 0          noisy_dyn    1.0                 3
# 4                 0          noisy_dyn    1.0                 4
# ...             ...                ...    ...               ...
# 4495              9  nom_dyn_risk_cost    0.2                 5
# 4496              9  nom_dyn_risk_cost    0.2                 6
# 4497              9  nom_dyn_risk_cost    0.2                 7
# 4498              9  nom_dyn_risk_cost    0.2                 8
# 4499              9  nom_dyn_risk_cost    0.2                 9
#
# [4500 rows x 8 columns]

# %%
# ------------- Create and visualize the map ------------
# Fixed a sampled environment
grid_shape = (9, 9)
mud_margin = 1
res = 1.0
semantic_grid = np.zeros(grid_shape, dtype=np.int8)
rand_num = np.random.rand(grid_shape[0]-2*mud_margin, grid_shape[1]-2*mud_margin)
perc_grass = 0.8
semantic_grid[mud_margin:-mud_margin, mud_margin:-mud_margin][rand_num<perc_grass] = 1


xlimits = (0,semantic_grid.shape[1]*res)
ylimits = (0,semantic_grid.shape[0]*res)
num_pmf_bins = len(d_ang_pmf) # Assume numbers of bins are the same for linear and angular components for now
bin_values = b_lin_values
bin_values_bounds = (np.min(b_lin_values), np.max(b_lin_values))
max_speed = 3.0
lin_tdm = TDM_Numba(max_speed=max_speed)
ang_tdm = TDM_Numba(max_speed=max_speed)

# ------------- Problem configuration ------------
cfg = Config()
u_seq0 = np.zeros((cfg.num_steps, 2), dtype=float)
# x0=np.array([0.5, 0.5, 0])
x0=np.array([mud_margin/2, mud_margin/2, np.pi/4])
# xgoal= np.array([3.5, 3.5])
xgoal= np.array([grid_shape[0]-mud_margin/2, grid_shape[0]-mud_margin/2])

mppi_params = dict(
    # Task specification
    dt=cfg.dt,
    x0=x0,
    xgoal=xgoal,
    timesteps=cfg.num_steps,
    u_seq0=u_seq0,

    # For risk-aware min time planning
    goal_tolerance=0.5,
    v_post_rollout=0.01,
    cvar_alpha=0.1, # use the mean if cvar_alpha=1.0

    # Hyper parameters
    lambda_weight=1.0,
    num_opt=1, # how many steps in each solve() function call

    # Control and sample specification
    u_std=np.array([3.0, 2.0]),
    vrange = np.array([0, max_speed]), 
    wrange=np.array([-np.pi, np.pi]),

    # Flags for using deterministic dynamics based on cvar
    use_det_dynamics=False,

    # Flag for using nominal rollouts but with risk-speed adjusted time cost
    use_nom_dynamics_with_speed_map=False,
)

# ------------- Configure the TDM based on whether determinisitc dynamics are used ------------
lin_tdm.set_TDM_from_semantic_grid(semantic_grid, res, num_pmf_bins, bin_values, bin_values_bounds, 
                    xlimits, ylimits, ID2NAME, NAME2TERRAIN, LIN_TERRAIN2PMG,
                    mppi_params["use_det_dynamics"], mppi_params['cvar_alpha'], mppi_params["use_nom_dynamics_with_speed_map"])
ang_tdm.set_TDM_from_semantic_grid(semantic_grid, res, num_pmf_bins, bin_values, bin_values_bounds, 
                    xlimits, ylimits, ID2NAME, NAME2TERRAIN, ANG_TERRAIN2PMG,
                    mppi_params["use_det_dynamics"], mppi_params['cvar_alpha'], mppi_params["use_nom_dynamics_with_speed_map"])
lin_tdm_vis = TDM_Visualizer(lin_tdm)
fig, ax = lin_tdm_vis.draw(figsize=(5, 5))

# Sample a specific map from the distribution that can be used to update the robot state
traction_grid = lin_tdm.sample_grids_true_dist()
fig, ax = plt.subplots()
lin = traction_grid.lin_traction
img = ax.imshow(lin, origin='lower', vmin=0, vmax=1.0, cmap='gray')
ax.set_title('sampled linear traction')
fig.subplots_adjust(right=0.85)
cbar_ax = fig.add_axes([0.88, 0.15, 0.04, 0.7])
fig.colorbar(img, cax=cbar_ax)
plt.show()

fig, ax = plt.subplots()
ang = traction_grid.ang_traction
img = ax.imshow(ang, origin='lower', vmin=0, vmax=1, cmap='gray')
ax.set_title('sampled angular traction')
fig.subplots_adjust(right=0.85)
cbar_ax = fig.add_axes([0.88, 0.15, 0.04, 0.7])
fig.colorbar(img, cax=cbar_ax)
plt.show()

# %%
# Construct the MPPI planner + initialize the GPU variables
# mppi_params['cvar_alpha']=0.1
# mppi_params['use_det_dynamics']=True


mppi_planner = MPPI_Numba()
mppi_planner.setup(mppi_params, lin_tdm, ang_tdm)
mppi_planner.init_device_vars_before_solving()

# Loop
max_steps = 200
xhist = np.zeros((max_steps+1, 3))*np.nan
uhist = np.zeros((max_steps, 2))*np.nan
xhist[0] = x0

plot_every_n = 30
for t in range(max_steps):
  # Solve
  useq = mppi_planner.solve()
  u_curr = useq[0]
  uhist[t] = u_curr

  # Simulate state forward using the sampled map
  lt, at = traction_grid.get(xhist[t,0], xhist[t,1])
  xhist[t+1, 0] = xhist[t, 0] + cfg.dt*lt*np.cos(xhist[t, 2])*u_curr[0]
  xhist[t+1, 1] = xhist[t, 1] + cfg.dt*lt*np.sin(xhist[t, 2])*u_curr[0]
  xhist[t+1, 2] = xhist[t, 2] + cfg.dt*at*u_curr[1]


  if t%plot_every_n==0:
    # Visualize the basic set up
    lin_tdm_vis = TDM_Visualizer(lin_tdm)
    fig, ax = lin_tdm_vis.draw(figsize=(5, 5))
    ax.plot([x0[0]], [x0[1]], 'ro', markersize=10, markerfacecolor='none', label="Start")
    ax.plot([xhist[t+1, 0]], [xhist[t+1, 1]], 'ro', markersize=10, label="Curr. State", zorder=5)
    c1 = plt.Circle(xgoal, mppi_params['goal_tolerance'], color='b', fill=False, label="Goal")
    ax.add_patch(c1)

    # Get rollout states from subset of maps for visualization? (e.g., 50)
    rollout_states_vis = mppi_planner.get_state_rollout()
    ax.plot(xhist[:,0], xhist[:,1], 'r', label="Past State")
    # ax.plot(rollout_states_vis[:,:,0].T, rollout_states_vis[:,:,1].T, 'b')
    ax.plot(rollout_states_vis[:,-1,0].T, rollout_states_vis[:,-1,1].T, 'r.', zorder=4)
    ax.plot(rollout_states_vis[:,:,0].T, rollout_states_vis[:,:,1].T, 'b', zorder=3)
    ax.plot(rollout_states_vis[0,:,0], rollout_states_vis[0,:,1], 'b', label="Rollouts")
    # ax.legend()
    plt.show()
  
  # Update MPPI state (x0, useq)
  mppi_planner.shift_and_update(xhist[t+1], useq, num_shifts=1)

  
  # Goal check
  if np.linalg.norm(xhist[t+1, :2] - mppi_params['xgoal']) <=mppi_params['goal_tolerance']:
    print("goal reached at t={}".format(t))
    break
